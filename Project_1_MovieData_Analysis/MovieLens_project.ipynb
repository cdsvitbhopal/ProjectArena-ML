# %% [markdown]
# <a href="https://colab.research.google.com/github/Maykkkk/ProjectArena-ML/blob/main/MovieLens_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pre processing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

import io

# %%
df_movies = pd.read_csv("/content/drive/MyDrive/MiniProject_DS/ml-20m/ml-20m/movies.csv")
print(df_movies)

df_tags = pd.read_csv("/content/drive/MyDrive/MiniProject_DS/ml-20m/ml-20m/tags.csv")
#print(df_tags)

df_ratings = pd.read_csv("/content/drive/MyDrive/MiniProject_DS/ml-20m/ml-20m/ratings.csv")
#print(df_ratings)
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %% [markdown]
# counting the number of NULL values

# %%
nan_count_movies = df_movies.isna().sum().sum()
print(nan_count_movies )

nan_count_tags = df_tags.isna().sum().sum()
print(nan_count_tags )

nan_count_ratings = df_ratings.isna().sum().sum()
print(nan_count_ratings )
# Out:
# 0
# 16
# 0

# %% [markdown]
# dropping the rows that contains null values(for tags.csv file only because it has null values)

# %%
df_tags_new = df_tags.dropna()
df_tags_new
# Out:
#         userId  movieId            tag   timestamp
# 0           18     4141    Mark Waters  1240597180
# 1           65      208      dark hero  1368150078
# 2           65      353      dark hero  1368150079
# 3           65      521  noir thriller  1368149983
# 4           65      592      dark hero  1368150078
# ...        ...      ...            ...         ...
# 465559  138446    55999        dragged  1358983772
# 465560  138446    55999  Jason Bateman  1358983778
# 465561  138446    55999         quirky  1358983778
# 465562  138446    55999            sad  1358983772
# 465563  138472      923  rise to power  1194037967
#
# [465548 rows x 4 columns]

# %%
nan_count_tags_1 = df_tags_new.isna().sum().sum()
print(nan_count_tags_1 )
# Out:
# 0

# %% [markdown]
# grouping the movie names according to titles that have the comedy genre in the provided dataset

# %%
ans = []
for x in df_movies.itertuples():
    if x[3].find('Comedy') != -1:
        ans.append(x[2])
        #print(x[2])

ans
# Out:
# ['Toy Story (1995)',
#  'Grumpier Old Men (1995)',
#  'Waiting to Exhale (1995)',
#  'Father of the Bride Part II (1995)',
#  'Sabrina (1995)',
#  'American President, The (1995)',
#  'Dracula: Dead and Loving It (1995)',
#  'Four Rooms (1995)',
#  'Ace Ventura: When Nature Calls (1995)',
#  'Money Train (1995)',
#  'Get Shorty (1995)',
#  'It Takes Two (1995)',
#  'Clueless (1995)',
#  'To Die For (1995)',
#  'Mighty Aphrodite (1995)',
#  'Big Green, The (1995)',
#  'Postman, The (Postino, Il) (1994)',
#  "Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996)",
#  'Two if by Sea (1996)',
#  'Bio-Dome (1996)',
#  'French Twist (Gazon maudit) (1995)',
#  'Friday (1995)',
#  'From Dusk Till Dawn (1996)',
#  'Kicking and Screaming (1995)',
#  'Big Bully (1996)',
#  "Antonia's Line (Antonia) (1995)",
#  'Last Summer in the Hamptons (1995)',
#  'Dunston Checks In (1996)',
#  'Black Sheep (1996)',
#  'Vampire in Brooklyn (1995)',
#  'Beautiful Girls (1996)',
# ...
